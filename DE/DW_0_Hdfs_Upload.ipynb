# %% [markdown]
# ## **`DW` Raw Data Hdfs Upload**
#
# **✔️ hdfs directory  :**
# - /raw_data
#
# <br/>
#
# **✔️ raw data items :**
#
# [관광지 정보 데이터]
# - travel_data_json.zip
#
# [관광지 평점 데이터]
# - tour_ratings.json
#
# [관광지 분위기 키워드 데이터]
# - tour_keywords.json
#
# [관광지 이미지 데이터]
# - .

# %% [markdown]
# ## **Hadoop 실행**

# %%
# service ssh start

# start-all.sh

# jps

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-01-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%205.04.45.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-01-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%205.04.45.png)

# %% [markdown]
# ## **Hdfs 에 파일 Upload**

# %% [markdown]
# ### 📍 관광지 정보 데이터
# - travel_data_json.zip

# %%
# !unzip -uq "./MoodTrip\(practice\)-20240204T053636Z-001.zip" -d
# Out:
# unzip:  cannot find or open ./MoodTrip\(practice\)-20240204T053636Z-001.zip, ./MoodTrip\(practice\)-20240204T053636Z-001.zip.zip or ./MoodTrip\(practice\)-20240204T053636Z-001.zip.ZIP.

# %%
# hdfs dfs -put /home/lab09/travel_data_json /raw_data

# %%
# hdfs dfs -ls /raw_data

# %% [markdown]
# ![스크린샷 2024-02-01 오후 5.03.32.png](attachment:b9cf1254-189b-4c59-851d-814e2c60e00d.png)

# %% [markdown]
# ### 📍 관광지 평점 데이터
# - tour_ratings.json

# %%
# hdfs dfs -put /home/lab09/tour_ratings.json /raw_data

# %%
# hdfs dfs -ls /raw_data

# %% [markdown]
# ![스크린샷 2024-02-01 오후 5.03.56.png](attachment:20f57f5c-51d6-4cf4-a35b-ef72dcbc3887.png)

# %% [markdown]
# ### 📍 관광지 키워드 데이터
# - tour_keywords.json

# %%
# hdfs dfs -put /home/lab09/tour_keywords.json /raw_data

# %%
# hdfs dfs -ls /raw_data
